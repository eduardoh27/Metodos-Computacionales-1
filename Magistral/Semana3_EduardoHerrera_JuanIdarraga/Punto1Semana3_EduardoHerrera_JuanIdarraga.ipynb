# %%
import numpy as np

def Function(x):
    return 1/(np.sqrt(1+np.exp(-x**2)))


def Derivative(x):
    return (x*np.exp(-x**2)) / ((np.exp(-x**2)+1)**(3/2))


def CentralDerivative(funcion,x,h):
    d = 0. 

    if h!=0:
        d = (funcion(x+h)-funcion(x-h))/(2*h)

    return d


def Error(Dy, Dcy):
    Sum_num = 0.
    Sum_den = 0.

    ErrorLocal = np.abs(Dcy-Dy)

    for i in range(len(ErrorLocal)):
        Sum_num += ErrorLocal[i]**2
        Sum_den += Dy[i]**2
    
    ErrorGlobal = np.sqrt( Sum_num / Sum_den )

    return ErrorLocal, ErrorGlobal


x_cero = 0.

xi, xf, h = -10. , 10. , 0.05
Npoints = int((xf-xi)/float(h) + 1)

x = np.linspace(xi,xf,Npoints)

Derivada_intervalo = CentralDerivative(Function, x ,h)


def opcion1():
    Derivada_en_cero = CentralDerivative(Function,x_cero,h)
    print("\na)")
    print("La derivada en 0 es: "+str(Derivada_en_cero))

def opcion2():    
    print("\nb)")
    for i in range(len(Derivada_intervalo)):
        print("La derivada en x="+str(round(x[i],2))+" es",Derivada_intervalo[i])

def opcion3 ():
    print("\nc)")
    Dy = Derivative(x)

    error_local, error_global = Error(Dy, Derivada_intervalo)

    for i in range(len(Derivada_intervalo)):
        print("El error local en x="+str(round(x[i],2))+" es",error_local[i])
    
    print("\nEl error global es: "+str(error_global))

def printMenu():
    print("\na) Derivada el punto x = 0")
    print("b) Derivada en el intervalo −10 ≤ x ≤ 10")
    print("c) Error en cada nodo y error global de la aproximación")
    print("d) Salir")

def main():
    print("\nTarea 3 Métodos Computacionales: Punto 1")

    printMenu()
    entrada = input("Ingrese el literal: ")

    while entrada != "d" and entrada != "d)":
        if entrada == "a" or entrada == "a)":
            opcion1()
        elif entrada == "b" or entrada == "b)":
            opcion2()
        elif entrada == "c" or entrada == "c)":
            opcion3()
        printMenu()
        entrada = input("Ingrese el literal: ")

main()
# Out:
# Tarea 3 Métodos Computacionales: Punto 1
#
# a) Derivada el punto x = 0
# b) Derivada en el intervalo −10 ≤ x ≤ 10
# c) Error en cada nodo y error global de la aproximación
# d) Salir
#
# a)
# La derivada en 0 es: 0.0
#
# a) Derivada el punto x = 0
# b) Derivada en el intervalo −10 ≤ x ≤ 10
# c) Error en cada nodo y error global de la aproximación
# d) Salir
#
# b)
# La derivada en x=-10.0 es 0.0
# La derivada en x=-9.95 es 0.0
# La derivada en x=-9.9 es 0.0
# La derivada en x=-9.85 es 0.0
# La derivada en x=-9.8 es 0.0
# La derivada en x=-9.75 es 0.0
# La derivada en x=-9.7 es 0.0
# La derivada en x=-9.65 es 0.0
# La derivada en x=-9.6 es 0.0
# La derivada en x=-9.55 es 0.0
# La derivada en x=-9.5 es 0.0
# La derivada en x=-9.45 es 0.0
# La derivada en x=-9.4 es 0.0
# La derivada en x=-9.35 es 0.0
# La derivada en x=-9.3 es 0.0
# La derivada en x=-9.25 es 0.0
# La derivada en x=-9.2 es 0.0
# La derivada en x=-9.15 es 0.0
# La derivada en x=-9.1 es 0.0
# La derivada en x=-9.05 es 0.0
# La derivada en x=-9.0 es 0.0
# La derivada en x=-8.95 es 0.0
# La derivada en x=-8.9 es 0.0
# La derivada en x=-8.85 es 0.0
# La derivada en x=-8.8 es 0.0
# La derivada en x=-8.75 es 0.0
# La derivada en x=-8.7 es 0.0
# La derivada en x=-8.65 es 0.0
# La derivada en x=-8.6 es 0.0
# La derivada en x=-8.55 es 0.0
# La derivada en x=-8.5 es 0.0
# La derivada en x=-8.45 es 0.0
# La derivada en x=-8.4 es 0.0
# La derivada en x=-8.35 es 0.0
# La derivada en x=-8.3 es 0.0
# La derivada en x=-8.25 es 0.0
# La derivada en x=-8.2 es 0.0
# La derivada en x=-8.15 es 0.0
# La derivada en x=-8.1 es 0.0
# La derivada en x=-8.05 es 0.0
# La derivada en x=-8.0 es 0.0
# La derivada en x=-7.95 es 0.0
# La derivada en x=-7.9 es 0.0
# La derivada en x=-7.85 es 0.0
# La derivada en x=-7.8 es 0.0
# La derivada en x=-7.75 es 0.0
# La derivada en x=-7.7 es 0.0
# La derivada en x=-7.65 es 0.0
# La derivada en x=-7.6 es 0.0
# La derivada en x=-7.55 es 0.0
# La derivada en x=-7.5 es 0.0
# La derivada en x=-7.45 es 0.0
# La derivada en x=-7.4 es 0.0
# La derivada en x=-7.35 es 0.0
# La derivada en x=-7.3 es 0.0
# La derivada en x=-7.25 es 0.0
# La derivada en x=-7.2 es 0.0
# La derivada en x=-7.15 es 0.0
# La derivada en x=-7.1 es 0.0
# La derivada en x=-7.05 es 0.0
# La derivada en x=-7.0 es 0.0
# La derivada en x=-6.95 es 0.0
# La derivada en x=-6.9 es 0.0
# La derivada en x=-6.85 es 0.0
# La derivada en x=-6.8 es 0.0
# La derivada en x=-6.75 es 0.0
# La derivada en x=-6.7 es 0.0
# La derivada en x=-6.65 es 0.0
# La derivada en x=-6.6 es 0.0
# La derivada en x=-6.55 es 0.0
# La derivada en x=-6.5 es 0.0
# La derivada en x=-6.45 es 0.0
# La derivada en x=-6.4 es 0.0
# La derivada en x=-6.35 es 0.0
# La derivada en x=-6.3 es 0.0
# La derivada en x=-6.25 es 0.0
# La derivada en x=-6.2 es 0.0
# La derivada en x=-6.15 es 0.0
# La derivada en x=-6.1 es 0.0
# La derivada en x=-6.05 es 0.0
# La derivada en x=-6.0 es -2.220446049250313e-15
# La derivada en x=-5.95 es -2.220446049250313e-15
# La derivada en x=-5.9 es -4.440892098500626e-15
# La derivada en x=-5.85 es -8.881784197001252e-15
# La derivada en x=-5.8 es -1.554312234475219e-14
# La derivada en x=-5.75 es -2.6645352591003757e-14
# La derivada en x=-5.7 es -4.6629367034256575e-14
# La derivada en x=-5.65 es -8.215650382226158e-14
# La derivada en x=-5.6 es -1.3988810110276972e-13
# La derivada en x=-5.55 es -2.4424906541753444e-13
# La derivada en x=-5.5 es -4.1966430330830917e-13
# La derivada en x=-5.45 es -7.194245199571014e-13
# La derivada en x=-5.4 es -1.2256862191861728e-12
# La derivada en x=-5.35 es -2.0761170560490427e-12
# La derivada en x=-5.3 es -3.4994229736184934e-12
# La derivada en x=-5.25 es -5.8686389081685775e-12
# La derivada en x=-5.2 es -9.794387523243131e-12
# La derivada en x=-5.15 es -1.6262546864709293e-11
# La derivada en x=-5.1 es -2.6862956303830288e-11
# La derivada en x=-5.05 es -4.4149128797243975e-11
# La derivada en x=-5.0 es -7.218892150717693e-11
# La derivada en x=-4.95 es -1.174371710987998e-10
# La derivada en x=-4.9 es -1.900835044921223e-10
# La derivada en x=-4.85 es -3.0609736967335266e-10
# La derivada en x=-4.8 es -4.904121553295226e-10
# La derivada en x=-4.75 es -7.817169134227697e-10
# La derivada en x=-4.7 es -1.2397105564332378e-09
# La derivada en x=-4.65 es -1.9560242314753395e-09
# La derivada en x=-4.6 es -3.0705082920690074e-09
# La derivada en x=-4.55 es -4.795424057846276e-09
# La derivada en x=-4.5 es -7.451148587023226e-09
# La derivada en x=-4.45 es -1.1518552778255753e-08
# La derivada en x=-4.4 es -1.7715346967150936e-08
# La derivada en x=-4.35 es -2.7106745736915627e-08
# La derivada en x=-4.3 es -4.126479824506646e-08
# La derivada en x=-4.25 es -6.249644912692531e-08
# La derivada en x=-4.2 es -9.416790236471684e-08
# La derivada en x=-4.15 es -1.4116300461886055e-07
# La derivada en x=-4.1 es -2.1052703025326025e-07
# La derivada en x=-4.05 es -3.123649328085065e-07
# La derivada en x=-4.0 es -4.6108660667343315e-07
# La derivada en x=-3.95 es -6.771219529522199e-07
# La derivada en x=-3.9 es -9.892674213141106e-07
# La derivada en x=-3.85 es -1.4378750479160374e-06
# La derivada en x=-3.8 es -2.0791572474809783e-06
# La derivada en x=-3.75 es -2.9909580478992837e-06
# La derivada en x=-3.7 es -4.280436567416501e-06
# La derivada en x=-3.65 es -6.094224370700729e-06
# La derivada en x=-3.6 es -8.631757213439784e-06
# La derivada en x=-3.55 es -1.216264585157667e-05
# La derivada en x=-3.5 es -1.704914174394112e-05
# La derivada en x=-3.45 es -2.3774971967815972e-05
# La derivada en x=-3.4 es -3.298206233681711e-05
# La derivada en x=-3.35 es -4.5516935154310545e-05
# La derivada en x=-3.3 es -6.248885154547246e-05
# La derivada en x=-3.25 es -8.534205735322153e-05
# La derivada en x=-3.2 es -0.00011594477061671604
# La derivada en x=-3.15 es -0.00015669779557470065
# La derivada en x=-3.1 es -0.00021066583410833672
# La derivada en x=-3.05 es -0.00028173465273617637
# La derivada en x=-3.0 es -0.00037479720423339025
# La derivada en x=-2.95 es -0.0004959715399888154
# La derivada en x=-2.9 es -0.0006528528131344302
# La derivada en x=-2.85 es -0.0008548007825670556
# La derivada en x=-2.8 es -0.0011132628930443644
# La derivada en x=-2.75 es -0.0014421311260848224
# La derivada en x=-2.7 es -0.0018581282835661295
# La derivada en x=-2.65 es -0.002381216074108794
# La derivada en x=-2.6 es -0.0030350132226719673
# La derivada en x=-2.55 es -0.0038472067388672926
# La derivada en x=-2.5 es -0.0048499334223961466
# La derivada en x=-2.45 es -0.006080101684793338
# La derivada en x=-2.4 es -0.007579615958133168
# La derivada en x=-2.35 es -0.009395457624443715
# La derivada en x=-2.3 es -0.01157956802007698
# La derivada en x=-2.25 es -0.014188471398930425
# La derivada en x=-2.2 es -0.017282569856814645
# La derivada en x=-2.15 es -0.020925039582040394
# La derivada en x=-2.1 es -0.025180260246587816
# La derivada en x=-2.05 es -0.030111719062199116
# La derivada en x=-2.0 es -0.035779350343899674
# La derivada en x=-1.95 es -0.04223630256659727
# La derivada en x=-1.9 es -0.04952516947613894
# La derivada en x=-1.85 es -0.05767378016830915
# La derivada en x=-1.8 es -0.0666907134717476
# La derivada en x=-1.75 es -0.07656077992323596
# La derivada en x=-1.7 es -0.08724079216090752
# La derivada en x=-1.65 es -0.09865601027647997
# La derivada en x=-1.6 es -0.1106976884762223
# La derivada en x=-1.55 es -0.1232221483974516
# La derivada en x=-1.5 es -0.13605174983609247
# La derivada en x=-1.45 es -0.14897801448453318
# La derivada en x=-1.4 es -0.16176698497621933
# La derivada en x=-1.35 es -0.17416668427419402
# La derivada en x=-1.3 es -0.18591630516918367
# La derivada en x=-1.25 es -0.19675654090342332
# La derivada en x=-1.2 es -0.20644030264864166
# La derivada en x=-1.15 es -0.21474298910584055
# La derivada en x=-1.1 es -0.22147149597952054
# La derivada en x=-1.05 es -0.22647127836959213
# La derivada en x=-1.0 es -0.22963098817593397
# La derivada en x=-0.95 es -0.23088446756660108
# La derivada en x=-0.9 es -0.23021014741334223
# La derivada en x=-0.85 es -0.2276281371288813
# La derivada en x=-0.8 es -0.22319546980697602
# La derivada en x=-0.75 es -0.21700006824297402
# La derivada en x=-0.7 es -0.20915402229175095
# La derivada en x=-0.65 es -0.1997867272040399
# La derivada en x=-0.6 es -0.18903834470423653
# La derivada en x=-0.55 es -0.17705393478952391
# La derivada en x=-0.5 es -0.16397848604048804
# La derivada en x=-0.45 es -0.14995296078846088
# La derivada en x=-0.4 es -0.13511137850452437
# La derivada en x=-0.35 es -0.11957889075369099
# La derivada en x=-0.3 es -0.10347075428248975
# La derivada en x=-0.25 es -0.08689208269868076
# La derivada en x=-0.2 es -0.06993824761395762
# La derivada en x=-0.15 es -0.052695802396203195
# La derivada en x=-0.1 es -0.03524381136840726
# La derivada en x=-0.05 es -0.017655480567901893
# La derivada en x=0.0 es 0.0
# La derivada en x=0.05 es 0.017655480567903004
# La derivada en x=0.1 es 0.03524381136840837
# La derivada en x=0.15 es 0.052695802396203195
# La derivada en x=0.2 es 0.06993824761395984
# La derivada en x=0.25 es 0.08689208269868076
# La derivada en x=0.3 es 0.10347075428248864
# La derivada en x=0.35 es 0.1195788907536921
# La derivada en x=0.4 es 0.13511137850452548
# La derivada en x=0.45 es 0.14995296078846088
# La derivada en x=0.5 es 0.16397848604048804
# La derivada en x=0.55 es 0.17705393478952502
# La derivada en x=0.6 es 0.18903834470423653
# La derivada en x=0.65 es 0.1997867272040399
# La derivada en x=0.7 es 0.20915402229175206
# La derivada en x=0.75 es 0.21700006824297402
# La derivada en x=0.8 es 0.22319546980697602
# La derivada en x=0.85 es 0.2276281371288813
# La derivada en x=0.9 es 0.23021014741334223
# La derivada en x=0.95 es 0.2308844675666022
# La derivada en x=1.0 es 0.22963098817593397
# La derivada en x=1.05 es 0.22647127836959324
# La derivada en x=1.1 es 0.22147149597951832
# La derivada en x=1.15 es 0.21474298910584055
# La derivada en x=1.2 es 0.20644030264864055
# La derivada en x=1.25 es 0.19675654090342332
# La derivada en x=1.3 es 0.18591630516918256
# La derivada en x=1.35 es 0.1741666842741918
# La derivada en x=1.4 es 0.16176698497621933
# La derivada en x=1.45 es 0.14897801448453096
# La derivada en x=1.5 es 0.13605174983609247
# La derivada en x=1.55 es 0.1232221483974516
# La derivada en x=1.6 es 0.1106976884762223
# La derivada en x=1.65 es 0.09865601027647997
# La derivada en x=1.7 es 0.08724079216090752
# La derivada en x=1.75 es 0.07656077992323596
# La derivada en x=1.8 es 0.0666907134717476
# La derivada en x=1.85 es 0.05767378016830693
# La derivada en x=1.9 es 0.04952516947613894
# La derivada en x=1.95 es 0.04223630256659727
# La derivada en x=2.0 es 0.035779350343899674
# La derivada en x=2.05 es 0.030111719062199116
# La derivada en x=2.1 es 0.025180260246590036
# La derivada en x=2.15 es 0.020925039582040394
# La derivada en x=2.2 es 0.017282569856812424
# La derivada en x=2.25 es 0.014188471398930425
# La derivada en x=2.3 es 0.01157956802007698
# La derivada en x=2.35 es 0.009395457624443715
# La derivada en x=2.4 es 0.007579615958133168
# La derivada en x=2.45 es 0.006080101684793338
# La derivada en x=2.5 es 0.0048499334223961466
# La derivada en x=2.55 es 0.0038472067388672926
# La derivada en x=2.6 es 0.0030350132226719673
# La derivada en x=2.65 es 0.002381216074108794
# La derivada en x=2.7 es 0.0018581282835661295
# La derivada en x=2.75 es 0.0014421311260848224
# La derivada en x=2.8 es 0.0011132628930443644
# La derivada en x=2.85 es 0.0008548007825648352
# La derivada en x=2.9 es 0.0006528528131344302
# La derivada en x=2.95 es 0.0004959715399888154
# La derivada en x=3.0 es 0.00037479720423339025
# La derivada en x=3.05 es 0.00028173465273617637
# La derivada en x=3.1 es 0.00021066583410833672
# La derivada en x=3.15 es 0.00015669779557470065
# La derivada en x=3.2 es 0.00011594477061671604
# La derivada en x=3.25 es 8.534205735322153e-05
# La derivada en x=3.3 es 6.248885154547246e-05
# La derivada en x=3.35 es 4.5516935154310545e-05
# La derivada en x=3.4 es 3.298206233681711e-05
# La derivada en x=3.45 es 2.3774971967815972e-05
# La derivada en x=3.5 es 1.704914174394112e-05
# La derivada en x=3.55 es 1.216264585157667e-05
# La derivada en x=3.6 es 8.631757213439784e-06
# La derivada en x=3.65 es 6.094224370700729e-06
# La derivada en x=3.7 es 4.280436567416501e-06
# La derivada en x=3.75 es 2.9909580478992837e-06
# La derivada en x=3.8 es 2.0791572474809783e-06
# La derivada en x=3.85 es 1.4378750479160374e-06
# La derivada en x=3.9 es 9.892674213141106e-07
# La derivada en x=3.95 es 6.771219529522199e-07
# La derivada en x=4.0 es 4.6108660667343315e-07
# La derivada en x=4.05 es 3.123649328085065e-07
# La derivada en x=4.1 es 2.1052703025326025e-07
# La derivada en x=4.15 es 1.4116300461886055e-07
# La derivada en x=4.2 es 9.416790236471684e-08
# La derivada en x=4.25 es 6.249644912692531e-08
# La derivada en x=4.3 es 4.126479824506646e-08
# La derivada en x=4.35 es 2.7106745736915627e-08
# La derivada en x=4.4 es 1.7715346967150936e-08
# La derivada en x=4.45 es 1.1518552778255753e-08
# La derivada en x=4.5 es 7.451148587023226e-09
# La derivada en x=4.55 es 4.795424057846276e-09
# La derivada en x=4.6 es 3.0705082920690074e-09
# La derivada en x=4.65 es 1.9560242314753395e-09
# La derivada en x=4.7 es 1.2397105564332378e-09
# La derivada en x=4.75 es 7.817169134227697e-10
# La derivada en x=4.8 es 4.904121553295226e-10
# La derivada en x=4.85 es 3.0609736967335266e-10
# La derivada en x=4.9 es 1.900835044921223e-10
# La derivada en x=4.95 es 1.174371710987998e-10
# La derivada en x=5.0 es 7.218892150717693e-11
# La derivada en x=5.05 es 4.4149128797243975e-11
# La derivada en x=5.1 es 2.6862956303830288e-11
# La derivada en x=5.15 es 1.6262546864709293e-11
# La derivada en x=5.2 es 9.794387523243131e-12
# La derivada en x=5.25 es 5.8686389081685775e-12
# La derivada en x=5.3 es 3.4994229736184934e-12
# La derivada en x=5.35 es 2.0761170560490427e-12
# La derivada en x=5.4 es 1.2256862191861728e-12
# La derivada en x=5.45 es 7.194245199571014e-13
# La derivada en x=5.5 es 4.1966430330830917e-13
# La derivada en x=5.55 es 2.4424906541753444e-13
# La derivada en x=5.6 es 1.3988810110276972e-13
# La derivada en x=5.65 es 8.215650382226158e-14
# La derivada en x=5.7 es 4.6629367034256575e-14
# La derivada en x=5.75 es 2.6645352591003757e-14
# La derivada en x=5.8 es 1.554312234475219e-14
# La derivada en x=5.85 es 8.881784197001252e-15
# La derivada en x=5.9 es 4.440892098500626e-15
# La derivada en x=5.95 es 2.220446049250313e-15
# La derivada en x=6.0 es 2.220446049250313e-15
# La derivada en x=6.05 es 0.0
# La derivada en x=6.1 es 0.0
# La derivada en x=6.15 es 0.0
# La derivada en x=6.2 es 0.0
# La derivada en x=6.25 es 0.0
# La derivada en x=6.3 es 0.0
# La derivada en x=6.35 es 0.0
# La derivada en x=6.4 es 0.0
# La derivada en x=6.45 es 0.0
# La derivada en x=6.5 es 0.0
# La derivada en x=6.55 es 0.0
# La derivada en x=6.6 es 0.0
# La derivada en x=6.65 es 0.0
# La derivada en x=6.7 es 0.0
# La derivada en x=6.75 es 0.0
# La derivada en x=6.8 es 0.0
# La derivada en x=6.85 es 0.0
# La derivada en x=6.9 es 0.0
# La derivada en x=6.95 es 0.0
# La derivada en x=7.0 es 0.0
# La derivada en x=7.05 es 0.0
# La derivada en x=7.1 es 0.0
# La derivada en x=7.15 es 0.0
# La derivada en x=7.2 es 0.0
# La derivada en x=7.25 es 0.0
# La derivada en x=7.3 es 0.0
# La derivada en x=7.35 es 0.0
# La derivada en x=7.4 es 0.0
# La derivada en x=7.45 es 0.0
# La derivada en x=7.5 es 0.0
# La derivada en x=7.55 es 0.0
# La derivada en x=7.6 es 0.0
# La derivada en x=7.65 es 0.0
# La derivada en x=7.7 es 0.0
# La derivada en x=7.75 es 0.0
# La derivada en x=7.8 es 0.0
# La derivada en x=7.85 es 0.0
# La derivada en x=7.9 es 0.0
# La derivada en x=7.95 es 0.0
# La derivada en x=8.0 es 0.0
# La derivada en x=8.05 es 0.0
# La derivada en x=8.1 es 0.0
# La derivada en x=8.15 es 0.0
# La derivada en x=8.2 es 0.0
# La derivada en x=8.25 es 0.0
# La derivada en x=8.3 es 0.0
# La derivada en x=8.35 es 0.0
# La derivada en x=8.4 es 0.0
# La derivada en x=8.45 es 0.0
# La derivada en x=8.5 es 0.0
# La derivada en x=8.55 es 0.0
# La derivada en x=8.6 es 0.0
# La derivada en x=8.65 es 0.0
# La derivada en x=8.7 es 0.0
# La derivada en x=8.75 es 0.0
# La derivada en x=8.8 es 0.0
# La derivada en x=8.85 es 0.0
# La derivada en x=8.9 es 0.0
# La derivada en x=8.95 es 0.0
# La derivada en x=9.0 es 0.0
# La derivada en x=9.05 es 0.0
# La derivada en x=9.1 es 0.0
# La derivada en x=9.15 es 0.0
# La derivada en x=9.2 es 0.0
# La derivada en x=9.25 es 0.0
# La derivada en x=9.3 es 0.0
# La derivada en x=9.35 es 0.0
# La derivada en x=9.4 es 0.0
# La derivada en x=9.45 es 0.0
# La derivada en x=9.5 es 0.0
# La derivada en x=9.55 es 0.0
# La derivada en x=9.6 es 0.0
# La derivada en x=9.65 es 0.0
# La derivada en x=9.7 es 0.0
# La derivada en x=9.75 es 0.0
# La derivada en x=9.8 es 0.0
# La derivada en x=9.85 es 0.0
# La derivada en x=9.9 es 0.0
# La derivada en x=9.95 es 0.0
# La derivada en x=10.0 es 0.0
#
# a) Derivada el punto x = 0
# b) Derivada en el intervalo −10 ≤ x ≤ 10
# c) Error en cada nodo y error global de la aproximación
# d) Salir
#
# c)
# El error local en x=-10.0 es 3.720075976020836e-43
# El error local en x=-9.95 es 1.0036531133327874e-42
# El error local en x=-9.9 es 2.694219798692763e-42
# El error local en x=-9.85 es 7.196144244154866e-42
# El error local en x=-9.8 es 1.9124233326894312e-41
# El error local en x=-9.75 es 5.056912391610859e-41
# El error local en x=-9.7 es 1.3304664636208873e-40
# El error local en x=-9.65 es 3.48288730493081e-40
# El error local en x=-9.6 es 9.07176477743157e-40
# El error local en x=-9.55 es 2.3510446969373964e-39
# El error local en x=-9.5 es 6.062428275657752e-39
# El error local en x=-9.45 es 1.5554241524398088e-38
# El error local en x=-9.4 es 3.9707032618337744e-38
# El error local en x=-9.35 es 1.008561223524625e-37
# El error local en x=-9.3 es 2.5489024147919937e-37
# El error local en x=-9.25 es 6.409440568404532e-37
# El error local en x=-9.2 es 1.6036252249136908e-36
# El error local en x=-9.15 es 3.992099276780828e-36
# El error local en x=-9.1 es 9.88815683078854e-36
# El error local en x=-9.05 es 2.4369396554127993e-35
# El error local en x=-9.0 es 5.975709479622661e-35
# El error local en x=-8.95 es 1.4579723864673722e-34
# El error local en x=-8.9 es 3.539354757132445e-34
# El error local en x=-8.85 es 8.548968401016373e-34
# El error local en x=-8.8 es 2.054556049468771e-33
# El error local en x=-8.75 es 4.912887080839443e-33
# El error local en x=-8.7 es 1.168879972050121e-32
# El error local en x=-8.65 es 2.7670514554678073e-32
# El error local en x=-8.6 es 6.517462930151849e-32
# El error local en x=-8.55 es 1.5274033943324688e-31
# El error local en x=-8.5 es 3.561579215320238e-31
# El error local en x=-8.45 es 8.263137220363483e-31
# El error local en x=-8.4 es 1.9074828545021687e-30
# El error local en x=-8.35 es 4.3811635013241656e-30
# El error local en x=-8.3 es 1.0012239600583391e-29
# El error local en x=-8.25 es 2.276594980705685e-29
# El error local en x=-8.2 es 5.150541481036937e-29
# El error local en x=-8.15 es 1.1593975666104208e-28
# El error local en x=-8.1 es 2.596713651949951e-28
# El error local en x=-8.05 es 5.786656682937241e-28
# El error local en x=-8.0 es 1.2830487124389103e-27
# El error local en x=-7.95 es 2.830545472378637e-27
# El error local en x=-7.9 es 6.213101889255472e-27
# El error local en x=-7.85 es 1.356931566569262e-26
# El error local en x=-7.8 es 2.9486167189253566e-26
# El error local en x=-7.75 es 6.375134961236525e-26
# El error local en x=-7.7 es 1.3714213087629712e-25
# El error local en x=-7.65 es 2.935368422588547e-25
# El error local en x=-7.6 es 6.25121329522108e-25
# El error local en x=-7.55 es 1.3245725387427533e-24
# El error local en x=-7.5 es 2.792522341312883e-24
# El error local en x=-7.45 es 5.857695484723536e-24
# El error local en x=-7.4 es 1.2225479189125525e-23
# El error local en x=-7.35 es 2.5387134884052093e-23
# El error local en x=-7.3 es 5.2452950142086054e-23
# El error local en x=-7.25 es 1.0782868316971712e-22
# El error local en x=-7.2 es 2.2054974224957807e-22
# El error local en x=-7.15 es 4.488346641169235e-22
# El error local en x=-7.1 es 9.088108765266687e-22
# El error local en x=-7.05 es 1.830912670719027e-21
# El error local en x=-7.0 es 3.6700199643544244e-21
# El error local en x=-6.95 es 7.319401866820984e-21
# El error local en x=-6.9 es 1.4524085850544072e-20
# El error local en x=-6.85 es 2.8675285092100096e-20
# El error local en x=-6.8 es 5.632900365224384e-20
# El error local en x=-6.75 es 1.1009343978023754e-19
# El error local en x=-6.7 es 2.1408957008914047e-19
# El error local en x=-6.65 es 4.1422272304761884e-19
# El error local en x=-6.6 es 7.974001331339864e-19
# El error local en x=-6.55 es 1.527292749841212e-18
# El error local en x=-6.5 es 2.910526087116896e-18
# El error local en x=-6.45 es 5.518531568502386e-18
# El error local en x=-6.4 es 1.0410653577300682e-17
# El error local en x=-6.35 es 1.9540446302268468e-17
# El error local en x=-6.3 es 3.649157117798769e-17
# El error local en x=-6.25 es 6.780345400268362e-17
# El error local en x=-6.2 es 1.2534638261911237e-16
# El error local en x=-6.15 es 2.305536881513436e-16
# El error local en x=-6.1 es 4.21921992508031e-16
# El error local en x=-6.05 es 7.6823059803361515e-16
# El error local en x=-6.0 es 8.287323511041719e-16
# El error local en x=-5.95 es 2.8801042746335706e-16
# El error local en x=-5.9 es 5.753924567933771e-17
# El error local en x=-5.85 es 8.555290920772389e-16
# El error local en x=-5.8 es 1.2948692057578175e-15
# El error local en x=-5.75 es 1.4797961994965356e-15
# El error local en x=-5.7 es 2.4064752027895728e-15
# El error local en x=-5.65 es 4.838105433115524e-15
# El error local en x=-5.6 es 5.3909533320002925e-15
# El error local en x=-5.55 es 1.14735996588807e-14
# El error local en x=-5.5 es 1.883947803826988e-14
# El error local en x=-5.45 es 3.272830506521204e-14
# El error local en x=-5.4 es 5.519902257230573e-14
# El error local en x=-5.35 es 9.11195120944592e-14
# El error local en x=-5.3 es 1.5020145447872332e-13
# El error local en x=-5.25 es 2.462919073608695e-13
# El error local en x=-5.2 es 4.04064048199774e-13
# El error local en x=-5.15 es 6.586944941532969e-13
# El error local en x=-5.1 es 1.065867315522624e-12
# El error local en x=-5.05 es 1.7168502455329315e-12
# El error local en x=-5.0 es 2.7492021838033917e-12
# El error local en x=-4.95 es 4.378297031984187e-12
# El error local en x=-4.9 es 6.942509433120013e-12
# El error local en x=-4.85 es 1.0942612082655711e-11
# El error local en x=-4.8 es 1.7155887751921064e-11
# El error local en x=-4.75 es 2.6756184113231346e-11
# El error local en x=-4.7 es 4.1501073107208144e-11
# El error local en x=-4.65 es 6.402690807511382e-11
# El error local en x=-4.6 es 9.824967932094383e-11
# El error local en x=-4.55 es 1.499516553857101e-10
# El error local en x=-4.5 es 2.2762235608108363e-10
# El error local en x=-4.45 es 3.436557122922686e-10
# El error local en x=-4.4 es 5.160179572321536e-10
# El error local en x=-4.35 es 7.706180472757888e-10
# El error local en x=-4.3 es 1.1445622361949527e-09
# El error local en x=-4.25 es 1.6906722779570774e-09
# El error local en x=-4.2 es 2.483677971588021e-09
# El error local en x=-4.15 es 3.6285972135636672e-09
# El error local en x=-4.1 es 5.27210681507488e-09
# El error local en x=-4.05 es 7.617725270510471e-09
# El error local en x=-4.0 es 1.0945983781379333e-08
# El error local en x=-3.95 es 1.5641016373853694e-08
# El error local en x=-3.9 es 2.2225333957623335e-08
# El error local en x=-3.85 es 3.1404852262704994e-08
# El error local en x=-3.8 es 4.412671716425786e-08
# El error local en x=-3.75 es 6.165295212112972e-08
# El error local en x=-3.7 es 8.565328766049632e-08
# El error local en x=-3.65 es 1.183210504028727e-07
# El error local en x=-3.6 es 1.6251638021107664e-07
# El error local en x=-3.55 es 2.2194127405061102e-07
# El error local en x=-3.5 es 3.013510818499587e-07
# El error local en x=-3.45 es 4.0680690078639736e-07
# El error local en x=-3.4 es 5.459727378212773e-07
# El error local en x=-3.35 es 7.284602828047741e-07
# El error local en x=-3.3 es 9.662223775547019e-07
# El error local en x=-3.25 es 1.2739936723363889e-06
# El error local en x=-3.2 es 1.6697734468252364e-06
# El error local en x=-3.15 es 2.1753406538471568e-06
# El error local en x=-3.1 es 2.8167850422786828e-06
# El error local en x=-3.05 es 3.6250304080820786e-06
# El error local en x=-3.0 es 4.636316311375233e-06
# El error local en x=-2.95 es 5.892593101651522e-06
# El error local en x=-2.9 es 7.441771716857042e-06
# El error local en x=-2.85 es 9.337754372179844e-06
# El error local en x=-2.8 es 1.1640155377020105e-05
# El error local en x=-2.75 es 1.4413603497343691e-05
# El error local en x=-2.7 es 1.772649905078423e-05
# El error local en x=-2.65 es 2.1649082077226413e-05
# El error local en x=-2.6 es 2.6250654451393917e-05
# El error local en x=-2.55 es 3.1595791754037046e-05
# El error local en x=-2.5 es 3.773938450868635e-05
# El error local en x=-2.45 es 4.4720368970897935e-05
# El error local en x=-2.4 es 5.255405277012574e-05
# El error local en x=-2.35 es 6.122301935545041e-05
# El error local en x=-2.3 es 7.066671838125253e-05
# El error local en x=-2.25 es 8.07700275025653e-05
# El error local en x=-2.2 es 9.135131288375356e-05
# El error local en x=-2.15 es 0.00010215082434157641
# El error local en x=-2.1 es 0.00011282062849925917
# El error local en x=-2.05 es 0.00012291768433770472
# El error local en x=-2.0 es 0.0001319020508735308
# El error local en x=-1.95 es 0.00013914250696044766
# El error local en x=-1.9 es 0.000143931947277659
# El error local en x=-1.85 es 0.00014551466218967052
# El error local en x=-1.8 es 0.0001431268736123842
# El error local en x=-1.75 es 0.0001360505790631572
# El error local en x=-1.7 es 0.00012367883099496935
# El error local en x=-1.65 es 0.00010558816936623305
# El error local en x=-1.6 es 8.16113404605856e-05
# El error local en x=-1.55 es 5.1901177308813495e-05
# El error local en x=-1.5 es 1.6975225830162533e-05
# El error local en x=-1.45 es 2.2268984595147368e-05
# El error local en x=-1.4 es 6.457576794716147e-05
# El error local en x=-1.35 es 0.0001083935175953954
# El error local en x=-1.3 es 0.0001519746925838228
# El error local en x=-1.25 es 0.00019350445615570755
# El error local en x=-1.2 es 0.00023124336724400507
# El error local en x=-1.15 es 0.0002636663250718263
# El error local en x=-1.1 es 0.0002895799658486631
# El error local en x=-1.05 es 0.00030820403032938426
# El error local en x=-1.0 es 0.00031920813680400006
# El error local en x=-0.95 es 0.00032270254660415887
# El error local en x=-0.9 es 0.00031918831620719734
# El error local en x=-0.85 es 0.00030947734336223
# El error local en x=-0.8 es 0.00029459545452587
# El error local en x=-0.75 es 0.0002756817512386822
# El error local en x=-0.7 es 0.0002538954180073827
# El error local en x=-0.65 es 0.00023033791279544746
# El error local en x=-0.6 es 0.0002059947905043713
# El error local en x=-0.55 es 0.0001816980704148763
# El error local en x=-0.5 es 0.0001581074993437237
# El error local en x=-0.45 es 0.00013570745335142465
# El error local en x=-0.4 es 0.00011481550901581983
# El error local en x=-0.35 es 9.559871499779937e-05
# El error local en x=-0.3 es 7.809406941380881e-05
# El error local en x=-0.25 es 6.223043481572155e-05
# El error local en x=-0.2 es 4.784992274944888e-05
# El error local en x=-0.15 es 3.472753458301503e-05
# El error local en x=-0.1 es 2.2588488251248928e-05
# El error local en x=-0.05 es 1.1123167198024558e-05
# El error local en x=0.0 es 0.0
# El error local en x=0.05 es 1.1123167197538836e-05
# El error local en x=0.1 es 2.2588488250756267e-05
# El error local en x=0.15 es 3.472753458362565e-05
# El error local en x=0.2 es 4.784992274782518e-05
# El error local en x=0.25 es 6.223043481572155e-05
# El error local en x=0.3 es 7.809406941552965e-05
# El error local en x=0.35 es 9.559871499725814e-05
# El error local en x=0.4 es 0.00011481550901523696
# El error local en x=0.45 es 0.00013570745335197976
# El error local en x=0.5 es 0.0001581074993437237
# El error local en x=0.55 es 0.0001816980704141824
# El error local en x=0.6 es 0.00020599479050478764
# El error local en x=0.65 es 0.00023033791279544746
# El error local en x=0.7 es 0.0002538954180066333
# El error local en x=0.75 es 0.0002756817512386822
# El error local en x=0.8 es 0.0002945954545261198
# El error local en x=0.85 es 0.0003094773433623965
# El error local en x=0.9 es 0.00031918831620719734
# El error local en x=0.95 es 0.0003227025466030764
# El error local en x=1.0 es 0.00031920813680400006
# El error local en x=1.05 es 0.000308204030328163
# El error local en x=1.1 es 0.000289579965850717
# El error local en x=1.15 es 0.0002636663250718263
# El error local en x=1.2 es 0.00023124336724478223
# El error local en x=1.25 es 0.00019350445615570755
# El error local en x=1.3 es 0.00015197469258448892
# El error local en x=1.35 es 0.00010839351759722726
# El error local en x=1.4 es 6.457576794716147e-05
# El error local en x=1.45 es 2.226898459689597e-05
# El error local en x=1.5 es 1.6975225830162533e-05
# El error local en x=1.55 es 5.190117730922983e-05
# El error local en x=1.6 es 8.161134046102969e-05
# El error local en x=1.65 es 0.00010558816936623305
# El error local en x=1.7 es 0.00012367883099538568
# El error local en x=1.75 es 0.0001360505790631572
# El error local en x=1.8 es 0.00014312687361271725
# El error local en x=1.85 es 0.00014551466218776232
# El error local en x=1.9 es 0.000143931947277659
# El error local en x=1.95 es 0.00013914250696069747
# El error local en x=2.0 es 0.0001319020508735308
# El error local en x=2.05 es 0.0001229176843377984
# El error local en x=2.1 es 0.00011282062850164615
# El error local en x=2.15 es 0.00010215082434164233
# El error local en x=2.2 es 9.13513128816372e-05
# El error local en x=2.25 es 8.07700275025653e-05
# El error local en x=2.3 es 7.066671838129937e-05
# El error local en x=2.35 es 6.122301935552674e-05
# El error local en x=2.4 es 5.255405277015696e-05
# El error local en x=2.45 es 4.47203689709413e-05
# El error local en x=2.5 es 3.773938450868635e-05
# El error local en x=2.55 es 3.1595791754052225e-05
# El error local en x=2.6 es 2.6250654451422106e-05
# El error local en x=2.65 es 2.1649082077235954e-05
# El error local en x=2.7 es 1.7726499050798976e-05
# El error local en x=2.75 es 1.4413603497343691e-05
# El error local en x=2.8 es 1.1640155377025743e-05
# El error local en x=2.85 es 9.337754369966446e-06
# El error local en x=2.9 es 7.441771716860295e-06
# El error local en x=2.95 es 5.892593101656401e-06
# El error local en x=3.0 es 4.636316311375233e-06
# El error local en x=3.05 es 3.625030408083488e-06
# El error local en x=3.1 es 2.8167850422807427e-06
# El error local en x=3.15 es 2.175340653848241e-06
# El error local en x=3.2 es 1.6697734468266052e-06
# El error local en x=3.25 es 1.2739936723363889e-06
# El error local en x=3.3 es 9.662223775550136e-07
# El error local en x=3.35 es 7.284602828052281e-07
# El error local en x=3.4 es 5.459727378214399e-07
# El error local en x=3.45 es 4.0680690078667857e-07
# El error local en x=3.5 es 3.013510818499587e-07
# El error local en x=3.55 es 2.219412740506703e-07
# El error local en x=3.6 es 1.6251638021117828e-07
# El error local en x=3.65 es 1.1832105040291421e-07
# El error local en x=3.7 es 8.565328766055307e-08
# El error local en x=3.75 es 6.165295212112972e-08
# El error local en x=3.8 es 4.412671716426845e-08
# El error local en x=3.85 es 3.140485226272151e-08
# El error local en x=3.9 es 2.222533395763011e-08
# El error local en x=3.95 es 1.56410163738628e-08
# El error local en x=4.0 es 1.0945983781379333e-08
# El error local en x=4.05 es 7.617725270512536e-09
# El error local en x=4.1 es 5.272106815077713e-09
# El error local en x=4.15 es 3.62859721356462e-09
# El error local en x=4.2 es 2.4836779715892783e-09
# El error local en x=4.25 es 1.6906722779570774e-09
# El error local en x=4.3 es 1.144562236195224e-09
# El error local en x=4.35 es 7.706180472762454e-10
# El error local en x=4.4 es 5.160179572322761e-10
# El error local en x=4.45 es 3.436557122924241e-10
# El error local en x=4.5 es 2.2762235608108363e-10
# El error local en x=4.55 es 1.499516553857589e-10
# El error local en x=4.6 es 9.824967932099553e-11
# El error local en x=4.65 es 6.402690807512706e-11
# El error local en x=4.7 es 4.150107310722903e-11
# El error local en x=4.75 es 2.6756184113231346e-11
# El error local en x=4.8 es 1.7155887751924373e-11
# El error local en x=4.85 es 1.094261208266083e-11
# El error local en x=4.9 es 6.9425094331219e-12
# El error local en x=4.95 es 4.378297031986164e-12
# El error local en x=5.0 es 2.7492021838033917e-12
# El error local en x=5.05 es 1.716850245533371e-12
# El error local en x=5.1 es 1.06586731552307e-12
# El error local en x=5.15 es 6.586944941534616e-13
# El error local en x=5.2 es 4.0406404819993716e-13
# El error local en x=5.25 es 2.462919073608695e-13
# El error local en x=5.3 es 1.5020145447874674e-13
# El error local en x=5.35 es 9.11195120945008e-14
# El error local en x=5.4 es 5.519902257231805e-14
# El error local en x=5.45 es 3.2728305065219207e-14
# El error local en x=5.5 es 1.883947803826988e-14
# El error local en x=5.55 es 1.1473599658883174e-14
# El error local en x=5.6 es 5.39095333200312e-15
# El error local en x=5.65 es 4.838105433116332e-15
# El error local en x=5.7 es 2.406475202789882e-15
# El error local en x=5.75 es 1.4797961994965356e-15
# El error local en x=5.8 es 1.2948692057579153e-15
# El error local en x=5.85 es 8.555290920774077e-16
# El error local en x=5.9 es 5.753924567930694e-17
# El error local en x=5.95 es 2.880104274633393e-16
# El error local en x=6.0 es 8.287323511041719e-16
# El error local en x=6.05 es 7.682305980336097e-16
# El error local en x=6.1 es 4.2192199250802217e-16
# El error local en x=6.15 es 2.305536881513388e-16
# El error local en x=6.2 es 1.2534638261911237e-16
# El error local en x=6.25 es 6.780345400268362e-17
# El error local en x=6.3 es 3.649157117798717e-17
# El error local en x=6.35 es 1.9540446302268058e-17
# El error local en x=6.4 es 1.0410653577300463e-17
# El error local en x=6.45 es 5.518531568502386e-18
# El error local en x=6.5 es 2.910526087116896e-18
# El error local en x=6.55 es 1.5272927498411903e-18
# El error local en x=6.6 es 7.974001331339697e-19
# El error local en x=6.65 es 4.1422272304761003e-19
# El error local en x=6.7 es 2.1408957008914047e-19
# El error local en x=6.75 es 1.1009343978023754e-19
# El error local en x=6.8 es 5.632900365224305e-20
# El error local en x=6.85 es 2.867528509209929e-20
# El error local en x=6.9 es 1.4524085850543768e-20
# El error local en x=6.95 es 7.319401866820984e-21
# El error local en x=7.0 es 3.6700199643544244e-21
# El error local en x=7.05 es 1.8309126707190143e-21
# El error local en x=7.1 es 9.088108765266497e-22
# El error local en x=7.15 es 4.488346641169108e-22
# El error local en x=7.2 es 2.2054974224957807e-22
# El error local en x=7.25 es 1.0782868316971712e-22
# El error local en x=7.3 es 5.2452950142085314e-23
# El error local en x=7.35 es 2.5387134884051373e-23
# El error local en x=7.4 es 1.2225479189125182e-23
# El error local en x=7.45 es 5.857695484723536e-24
# El error local en x=7.5 es 2.792522341312883e-24
# El error local en x=7.55 es 1.3245725387427346e-24
# El error local en x=7.6 es 6.251213295220949e-25
# El error local en x=7.65 es 2.935368422588485e-25
# El error local en x=7.7 es 1.3714213087629712e-25
# El error local en x=7.75 es 6.375134961236525e-26
# El error local en x=7.8 es 2.948616718925315e-26
# El error local en x=7.85 es 1.356931566569224e-26
# El error local en x=7.9 es 6.2131018892552966e-27
# El error local en x=7.95 es 2.830545472378637e-27
# El error local en x=8.0 es 1.2830487124389103e-27
# El error local en x=8.05 es 5.786656682937241e-28
# El error local en x=8.1 es 2.596713651949878e-28
# El error local en x=8.15 es 1.1593975666103878e-28
# El error local en x=8.2 es 5.150541481036937e-29
# El error local en x=8.25 es 2.276594980705685e-29
# El error local en x=8.3 es 1.0012239600583391e-29
# El error local en x=8.35 es 4.3811635013240416e-30
# El error local en x=8.4 es 1.907482854502115e-30
# El error local en x=8.45 es 8.263137220363483e-31
# El error local en x=8.5 es 3.561579215320238e-31
# El error local en x=8.55 es 1.5274033943324688e-31
# El error local en x=8.6 es 6.517462930151667e-32
# El error local en x=8.65 es 2.767051455467729e-32
# El error local en x=8.7 es 1.168879972050121e-32
# El error local en x=8.75 es 4.912887080839443e-33
# El error local en x=8.8 es 2.054556049468771e-33
# El error local en x=8.85 es 8.548968401016132e-34
# El error local en x=8.9 es 3.5393547571323455e-34
# El error local en x=8.95 es 1.4579723864673722e-34
# El error local en x=9.0 es 5.975709479622661e-35
# El error local en x=9.05 es 2.4369396554127993e-35
# El error local en x=9.1 es 9.88815683078812e-36
# El error local en x=9.15 es 3.992099276780715e-36
# El error local en x=9.2 es 1.6036252249135776e-36
# El error local en x=9.25 es 6.409440568404532e-37
# El error local en x=9.3 es 2.5489024147919937e-37
# El error local en x=9.35 es 1.0085612235245966e-37
# El error local en x=9.4 es 3.9707032618336627e-38
# El error local en x=9.45 es 1.5554241524396992e-38
# El error local en x=9.5 es 6.062428275657752e-39
# El error local en x=9.55 es 2.3510446969373964e-39
# El error local en x=9.6 es 9.071764777431313e-40
# El error local en x=9.65 es 3.4828873049306618e-40
# El error local en x=9.7 es 1.3304664636207933e-40
# El error local en x=9.75 es 5.056912391610859e-41
# El error local en x=9.8 es 1.9124233326894312e-41
# El error local en x=9.85 es 7.196144244154663e-42
# El error local en x=9.9 es 2.6942197986926486e-42
# El error local en x=9.95 es 1.0036531133327164e-42
# El error local en x=10.0 es 3.720075976020836e-43
#
# El error global es: 0.0012035702363380383
#
# a) Derivada el punto x = 0
# b) Derivada en el intervalo −10 ≤ x ≤ 10
# c) Error en cada nodo y error global de la aproximación
# d) Salir
#
# c)
# El error local en x=-10.0 es 3.720075976020836e-43
# El error local en x=-9.95 es 1.0036531133327874e-42
# El error local en x=-9.9 es 2.694219798692763e-42
# El error local en x=-9.85 es 7.196144244154866e-42
# El error local en x=-9.8 es 1.9124233326894312e-41
# El error local en x=-9.75 es 5.056912391610859e-41
# El error local en x=-9.7 es 1.3304664636208873e-40
# El error local en x=-9.65 es 3.48288730493081e-40
# El error local en x=-9.6 es 9.07176477743157e-40
# El error local en x=-9.55 es 2.3510446969373964e-39
# El error local en x=-9.5 es 6.062428275657752e-39
# El error local en x=-9.45 es 1.5554241524398088e-38
# El error local en x=-9.4 es 3.9707032618337744e-38
# El error local en x=-9.35 es 1.008561223524625e-37
# El error local en x=-9.3 es 2.5489024147919937e-37
# El error local en x=-9.25 es 6.409440568404532e-37
# El error local en x=-9.2 es 1.6036252249136908e-36
# El error local en x=-9.15 es 3.992099276780828e-36
# El error local en x=-9.1 es 9.88815683078854e-36
# El error local en x=-9.05 es 2.4369396554127993e-35
# El error local en x=-9.0 es 5.975709479622661e-35
# El error local en x=-8.95 es 1.4579723864673722e-34
# El error local en x=-8.9 es 3.539354757132445e-34
# El error local en x=-8.85 es 8.548968401016373e-34
# El error local en x=-8.8 es 2.054556049468771e-33
# El error local en x=-8.75 es 4.912887080839443e-33
# El error local en x=-8.7 es 1.168879972050121e-32
# El error local en x=-8.65 es 2.7670514554678073e-32
# El error local en x=-8.6 es 6.517462930151849e-32
# El error local en x=-8.55 es 1.5274033943324688e-31
# El error local en x=-8.5 es 3.561579215320238e-31
# El error local en x=-8.45 es 8.263137220363483e-31
# El error local en x=-8.4 es 1.9074828545021687e-30
# El error local en x=-8.35 es 4.3811635013241656e-30
# El error local en x=-8.3 es 1.0012239600583391e-29
# El error local en x=-8.25 es 2.276594980705685e-29
# El error local en x=-8.2 es 5.150541481036937e-29
# El error local en x=-8.15 es 1.1593975666104208e-28
# El error local en x=-8.1 es 2.596713651949951e-28
# El error local en x=-8.05 es 5.786656682937241e-28
# El error local en x=-8.0 es 1.2830487124389103e-27
# El error local en x=-7.95 es 2.830545472378637e-27
# El error local en x=-7.9 es 6.213101889255472e-27
# El error local en x=-7.85 es 1.356931566569262e-26
# El error local en x=-7.8 es 2.9486167189253566e-26
# El error local en x=-7.75 es 6.375134961236525e-26
# El error local en x=-7.7 es 1.3714213087629712e-25
# El error local en x=-7.65 es 2.935368422588547e-25
# El error local en x=-7.6 es 6.25121329522108e-25
# El error local en x=-7.55 es 1.3245725387427533e-24
# El error local en x=-7.5 es 2.792522341312883e-24
# El error local en x=-7.45 es 5.857695484723536e-24
# El error local en x=-7.4 es 1.2225479189125525e-23
# El error local en x=-7.35 es 2.5387134884052093e-23
# El error local en x=-7.3 es 5.2452950142086054e-23
# El error local en x=-7.25 es 1.0782868316971712e-22
# El error local en x=-7.2 es 2.2054974224957807e-22
# El error local en x=-7.15 es 4.488346641169235e-22
# El error local en x=-7.1 es 9.088108765266687e-22
# El error local en x=-7.05 es 1.830912670719027e-21
# El error local en x=-7.0 es 3.6700199643544244e-21
# El error local en x=-6.95 es 7.319401866820984e-21
# El error local en x=-6.9 es 1.4524085850544072e-20
# El error local en x=-6.85 es 2.8675285092100096e-20
# El error local en x=-6.8 es 5.632900365224384e-20
# El error local en x=-6.75 es 1.1009343978023754e-19
# El error local en x=-6.7 es 2.1408957008914047e-19
# El error local en x=-6.65 es 4.1422272304761884e-19
# El error local en x=-6.6 es 7.974001331339864e-19
# El error local en x=-6.55 es 1.527292749841212e-18
# El error local en x=-6.5 es 2.910526087116896e-18
# El error local en x=-6.45 es 5.518531568502386e-18
# El error local en x=-6.4 es 1.0410653577300682e-17
# El error local en x=-6.35 es 1.9540446302268468e-17
# El error local en x=-6.3 es 3.649157117798769e-17
# El error local en x=-6.25 es 6.780345400268362e-17
# El error local en x=-6.2 es 1.2534638261911237e-16
# El error local en x=-6.15 es 2.305536881513436e-16
# El error local en x=-6.1 es 4.21921992508031e-16
# El error local en x=-6.05 es 7.6823059803361515e-16
# El error local en x=-6.0 es 8.287323511041719e-16
# El error local en x=-5.95 es 2.8801042746335706e-16
# El error local en x=-5.9 es 5.753924567933771e-17
# El error local en x=-5.85 es 8.555290920772389e-16
# El error local en x=-5.8 es 1.2948692057578175e-15
# El error local en x=-5.75 es 1.4797961994965356e-15
# El error local en x=-5.7 es 2.4064752027895728e-15
# El error local en x=-5.65 es 4.838105433115524e-15
# El error local en x=-5.6 es 5.3909533320002925e-15
# El error local en x=-5.55 es 1.14735996588807e-14
# El error local en x=-5.5 es 1.883947803826988e-14
# El error local en x=-5.45 es 3.272830506521204e-14
# El error local en x=-5.4 es 5.519902257230573e-14
# El error local en x=-5.35 es 9.11195120944592e-14
# El error local en x=-5.3 es 1.5020145447872332e-13
# El error local en x=-5.25 es 2.462919073608695e-13
# El error local en x=-5.2 es 4.04064048199774e-13
# El error local en x=-5.15 es 6.586944941532969e-13
# El error local en x=-5.1 es 1.065867315522624e-12
# El error local en x=-5.05 es 1.7168502455329315e-12
# El error local en x=-5.0 es 2.7492021838033917e-12
# El error local en x=-4.95 es 4.378297031984187e-12
# El error local en x=-4.9 es 6.942509433120013e-12
# El error local en x=-4.85 es 1.0942612082655711e-11
# El error local en x=-4.8 es 1.7155887751921064e-11
# El error local en x=-4.75 es 2.6756184113231346e-11
# El error local en x=-4.7 es 4.1501073107208144e-11
# El error local en x=-4.65 es 6.402690807511382e-11
# El error local en x=-4.6 es 9.824967932094383e-11
# El error local en x=-4.55 es 1.499516553857101e-10
# El error local en x=-4.5 es 2.2762235608108363e-10
# El error local en x=-4.45 es 3.436557122922686e-10
# El error local en x=-4.4 es 5.160179572321536e-10
# El error local en x=-4.35 es 7.706180472757888e-10
# El error local en x=-4.3 es 1.1445622361949527e-09
# El error local en x=-4.25 es 1.6906722779570774e-09
# El error local en x=-4.2 es 2.483677971588021e-09
# El error local en x=-4.15 es 3.6285972135636672e-09
# El error local en x=-4.1 es 5.27210681507488e-09
# El error local en x=-4.05 es 7.617725270510471e-09
# El error local en x=-4.0 es 1.0945983781379333e-08
# El error local en x=-3.95 es 1.5641016373853694e-08
# El error local en x=-3.9 es 2.2225333957623335e-08
# El error local en x=-3.85 es 3.1404852262704994e-08
# El error local en x=-3.8 es 4.412671716425786e-08
# El error local en x=-3.75 es 6.165295212112972e-08
# El error local en x=-3.7 es 8.565328766049632e-08
# El error local en x=-3.65 es 1.183210504028727e-07
# El error local en x=-3.6 es 1.6251638021107664e-07
# El error local en x=-3.55 es 2.2194127405061102e-07
# El error local en x=-3.5 es 3.013510818499587e-07
# El error local en x=-3.45 es 4.0680690078639736e-07
# El error local en x=-3.4 es 5.459727378212773e-07
# El error local en x=-3.35 es 7.284602828047741e-07
# El error local en x=-3.3 es 9.662223775547019e-07
# El error local en x=-3.25 es 1.2739936723363889e-06
# El error local en x=-3.2 es 1.6697734468252364e-06
# El error local en x=-3.15 es 2.1753406538471568e-06
# El error local en x=-3.1 es 2.8167850422786828e-06
# El error local en x=-3.05 es 3.6250304080820786e-06
# El error local en x=-3.0 es 4.636316311375233e-06
# El error local en x=-2.95 es 5.892593101651522e-06
# El error local en x=-2.9 es 7.441771716857042e-06
# El error local en x=-2.85 es 9.337754372179844e-06
# El error local en x=-2.8 es 1.1640155377020105e-05
# El error local en x=-2.75 es 1.4413603497343691e-05
# El error local en x=-2.7 es 1.772649905078423e-05
# El error local en x=-2.65 es 2.1649082077226413e-05
# El error local en x=-2.6 es 2.6250654451393917e-05
# El error local en x=-2.55 es 3.1595791754037046e-05
# El error local en x=-2.5 es 3.773938450868635e-05
# El error local en x=-2.45 es 4.4720368970897935e-05
# El error local en x=-2.4 es 5.255405277012574e-05
# El error local en x=-2.35 es 6.122301935545041e-05
# El error local en x=-2.3 es 7.066671838125253e-05
# El error local en x=-2.25 es 8.07700275025653e-05
# El error local en x=-2.2 es 9.135131288375356e-05
# El error local en x=-2.15 es 0.00010215082434157641
# El error local en x=-2.1 es 0.00011282062849925917
# El error local en x=-2.05 es 0.00012291768433770472
# El error local en x=-2.0 es 0.0001319020508735308
# El error local en x=-1.95 es 0.00013914250696044766
# El error local en x=-1.9 es 0.000143931947277659
# El error local en x=-1.85 es 0.00014551466218967052
# El error local en x=-1.8 es 0.0001431268736123842
# El error local en x=-1.75 es 0.0001360505790631572
# El error local en x=-1.7 es 0.00012367883099496935
# El error local en x=-1.65 es 0.00010558816936623305
# El error local en x=-1.6 es 8.16113404605856e-05
# El error local en x=-1.55 es 5.1901177308813495e-05
# El error local en x=-1.5 es 1.6975225830162533e-05
# El error local en x=-1.45 es 2.2268984595147368e-05
# El error local en x=-1.4 es 6.457576794716147e-05
# El error local en x=-1.35 es 0.0001083935175953954
# El error local en x=-1.3 es 0.0001519746925838228
# El error local en x=-1.25 es 0.00019350445615570755
# El error local en x=-1.2 es 0.00023124336724400507
# El error local en x=-1.15 es 0.0002636663250718263
# El error local en x=-1.1 es 0.0002895799658486631
# El error local en x=-1.05 es 0.00030820403032938426
# El error local en x=-1.0 es 0.00031920813680400006
# El error local en x=-0.95 es 0.00032270254660415887
# El error local en x=-0.9 es 0.00031918831620719734
# El error local en x=-0.85 es 0.00030947734336223
# El error local en x=-0.8 es 0.00029459545452587
# El error local en x=-0.75 es 0.0002756817512386822
# El error local en x=-0.7 es 0.0002538954180073827
# El error local en x=-0.65 es 0.00023033791279544746
# El error local en x=-0.6 es 0.0002059947905043713
# El error local en x=-0.55 es 0.0001816980704148763
# El error local en x=-0.5 es 0.0001581074993437237
# El error local en x=-0.45 es 0.00013570745335142465
# El error local en x=-0.4 es 0.00011481550901581983
# El error local en x=-0.35 es 9.559871499779937e-05
# El error local en x=-0.3 es 7.809406941380881e-05
# El error local en x=-0.25 es 6.223043481572155e-05
# El error local en x=-0.2 es 4.784992274944888e-05
# El error local en x=-0.15 es 3.472753458301503e-05
# El error local en x=-0.1 es 2.2588488251248928e-05
# El error local en x=-0.05 es 1.1123167198024558e-05
# El error local en x=0.0 es 0.0
# El error local en x=0.05 es 1.1123167197538836e-05
# El error local en x=0.1 es 2.2588488250756267e-05
# El error local en x=0.15 es 3.472753458362565e-05
# El error local en x=0.2 es 4.784992274782518e-05
# El error local en x=0.25 es 6.223043481572155e-05
# El error local en x=0.3 es 7.809406941552965e-05
# El error local en x=0.35 es 9.559871499725814e-05
# El error local en x=0.4 es 0.00011481550901523696
# El error local en x=0.45 es 0.00013570745335197976
# El error local en x=0.5 es 0.0001581074993437237
# El error local en x=0.55 es 0.0001816980704141824
# El error local en x=0.6 es 0.00020599479050478764
# El error local en x=0.65 es 0.00023033791279544746
# El error local en x=0.7 es 0.0002538954180066333
# El error local en x=0.75 es 0.0002756817512386822
# El error local en x=0.8 es 0.0002945954545261198
# El error local en x=0.85 es 0.0003094773433623965
# El error local en x=0.9 es 0.00031918831620719734
# El error local en x=0.95 es 0.0003227025466030764
# El error local en x=1.0 es 0.00031920813680400006
# El error local en x=1.05 es 0.000308204030328163
# El error local en x=1.1 es 0.000289579965850717
# El error local en x=1.15 es 0.0002636663250718263
# El error local en x=1.2 es 0.00023124336724478223
# El error local en x=1.25 es 0.00019350445615570755
# El error local en x=1.3 es 0.00015197469258448892
# El error local en x=1.35 es 0.00010839351759722726
# El error local en x=1.4 es 6.457576794716147e-05
# El error local en x=1.45 es 2.226898459689597e-05
# El error local en x=1.5 es 1.6975225830162533e-05
# El error local en x=1.55 es 5.190117730922983e-05
# El error local en x=1.6 es 8.161134046102969e-05
# El error local en x=1.65 es 0.00010558816936623305
# El error local en x=1.7 es 0.00012367883099538568
# El error local en x=1.75 es 0.0001360505790631572
# El error local en x=1.8 es 0.00014312687361271725
# El error local en x=1.85 es 0.00014551466218776232
# El error local en x=1.9 es 0.000143931947277659
# El error local en x=1.95 es 0.00013914250696069747
# El error local en x=2.0 es 0.0001319020508735308
# El error local en x=2.05 es 0.0001229176843377984
# El error local en x=2.1 es 0.00011282062850164615
# El error local en x=2.15 es 0.00010215082434164233
# El error local en x=2.2 es 9.13513128816372e-05
# El error local en x=2.25 es 8.07700275025653e-05
# El error local en x=2.3 es 7.066671838129937e-05
# El error local en x=2.35 es 6.122301935552674e-05
# El error local en x=2.4 es 5.255405277015696e-05
# El error local en x=2.45 es 4.47203689709413e-05
# El error local en x=2.5 es 3.773938450868635e-05
# El error local en x=2.55 es 3.1595791754052225e-05
# El error local en x=2.6 es 2.6250654451422106e-05
# El error local en x=2.65 es 2.1649082077235954e-05
# El error local en x=2.7 es 1.7726499050798976e-05
# El error local en x=2.75 es 1.4413603497343691e-05
# El error local en x=2.8 es 1.1640155377025743e-05
# El error local en x=2.85 es 9.337754369966446e-06
# El error local en x=2.9 es 7.441771716860295e-06
# El error local en x=2.95 es 5.892593101656401e-06
# El error local en x=3.0 es 4.636316311375233e-06
# El error local en x=3.05 es 3.625030408083488e-06
# El error local en x=3.1 es 2.8167850422807427e-06
# El error local en x=3.15 es 2.175340653848241e-06
# El error local en x=3.2 es 1.6697734468266052e-06
# El error local en x=3.25 es 1.2739936723363889e-06
# El error local en x=3.3 es 9.662223775550136e-07
# El error local en x=3.35 es 7.284602828052281e-07
# El error local en x=3.4 es 5.459727378214399e-07
# El error local en x=3.45 es 4.0680690078667857e-07
# El error local en x=3.5 es 3.013510818499587e-07
# El error local en x=3.55 es 2.219412740506703e-07
# El error local en x=3.6 es 1.6251638021117828e-07
# El error local en x=3.65 es 1.1832105040291421e-07
# El error local en x=3.7 es 8.565328766055307e-08
# El error local en x=3.75 es 6.165295212112972e-08
# El error local en x=3.8 es 4.412671716426845e-08
# El error local en x=3.85 es 3.140485226272151e-08
# El error local en x=3.9 es 2.222533395763011e-08
# El error local en x=3.95 es 1.56410163738628e-08
# El error local en x=4.0 es 1.0945983781379333e-08
# El error local en x=4.05 es 7.617725270512536e-09
# El error local en x=4.1 es 5.272106815077713e-09
# El error local en x=4.15 es 3.62859721356462e-09
# El error local en x=4.2 es 2.4836779715892783e-09
# El error local en x=4.25 es 1.6906722779570774e-09
# El error local en x=4.3 es 1.144562236195224e-09
# El error local en x=4.35 es 7.706180472762454e-10
# El error local en x=4.4 es 5.160179572322761e-10
# El error local en x=4.45 es 3.436557122924241e-10
# El error local en x=4.5 es 2.2762235608108363e-10
# El error local en x=4.55 es 1.499516553857589e-10
# El error local en x=4.6 es 9.824967932099553e-11
# El error local en x=4.65 es 6.402690807512706e-11
# El error local en x=4.7 es 4.150107310722903e-11
# El error local en x=4.75 es 2.6756184113231346e-11
# El error local en x=4.8 es 1.7155887751924373e-11
# El error local en x=4.85 es 1.094261208266083e-11
# El error local en x=4.9 es 6.9425094331219e-12
# El error local en x=4.95 es 4.378297031986164e-12
# El error local en x=5.0 es 2.7492021838033917e-12
# El error local en x=5.05 es 1.716850245533371e-12
# El error local en x=5.1 es 1.06586731552307e-12
# El error local en x=5.15 es 6.586944941534616e-13
# El error local en x=5.2 es 4.0406404819993716e-13
# El error local en x=5.25 es 2.462919073608695e-13
# El error local en x=5.3 es 1.5020145447874674e-13
# El error local en x=5.35 es 9.11195120945008e-14
# El error local en x=5.4 es 5.519902257231805e-14
# El error local en x=5.45 es 3.2728305065219207e-14
# El error local en x=5.5 es 1.883947803826988e-14
# El error local en x=5.55 es 1.1473599658883174e-14
# El error local en x=5.6 es 5.39095333200312e-15
# El error local en x=5.65 es 4.838105433116332e-15
# El error local en x=5.7 es 2.406475202789882e-15
# El error local en x=5.75 es 1.4797961994965356e-15
# El error local en x=5.8 es 1.2948692057579153e-15
# El error local en x=5.85 es 8.555290920774077e-16
# El error local en x=5.9 es 5.753924567930694e-17
# El error local en x=5.95 es 2.880104274633393e-16
# El error local en x=6.0 es 8.287323511041719e-16
# El error local en x=6.05 es 7.682305980336097e-16
# El error local en x=6.1 es 4.2192199250802217e-16
# El error local en x=6.15 es 2.305536881513388e-16
# El error local en x=6.2 es 1.2534638261911237e-16
# El error local en x=6.25 es 6.780345400268362e-17
# El error local en x=6.3 es 3.649157117798717e-17
# El error local en x=6.35 es 1.9540446302268058e-17
# El error local en x=6.4 es 1.0410653577300463e-17
# El error local en x=6.45 es 5.518531568502386e-18
# El error local en x=6.5 es 2.910526087116896e-18
# El error local en x=6.55 es 1.5272927498411903e-18
# El error local en x=6.6 es 7.974001331339697e-19
# El error local en x=6.65 es 4.1422272304761003e-19
# El error local en x=6.7 es 2.1408957008914047e-19
# El error local en x=6.75 es 1.1009343978023754e-19
# El error local en x=6.8 es 5.632900365224305e-20
# El error local en x=6.85 es 2.867528509209929e-20
# El error local en x=6.9 es 1.4524085850543768e-20
# El error local en x=6.95 es 7.319401866820984e-21
# El error local en x=7.0 es 3.6700199643544244e-21
# El error local en x=7.05 es 1.8309126707190143e-21
# El error local en x=7.1 es 9.088108765266497e-22
# El error local en x=7.15 es 4.488346641169108e-22
# El error local en x=7.2 es 2.2054974224957807e-22
# El error local en x=7.25 es 1.0782868316971712e-22
# El error local en x=7.3 es 5.2452950142085314e-23
# El error local en x=7.35 es 2.5387134884051373e-23
# El error local en x=7.4 es 1.2225479189125182e-23
# El error local en x=7.45 es 5.857695484723536e-24
# El error local en x=7.5 es 2.792522341312883e-24
# El error local en x=7.55 es 1.3245725387427346e-24
# El error local en x=7.6 es 6.251213295220949e-25
# El error local en x=7.65 es 2.935368422588485e-25
# El error local en x=7.7 es 1.3714213087629712e-25
# El error local en x=7.75 es 6.375134961236525e-26
# El error local en x=7.8 es 2.948616718925315e-26
# El error local en x=7.85 es 1.356931566569224e-26
# El error local en x=7.9 es 6.2131018892552966e-27
# El error local en x=7.95 es 2.830545472378637e-27
# El error local en x=8.0 es 1.2830487124389103e-27
# El error local en x=8.05 es 5.786656682937241e-28
# El error local en x=8.1 es 2.596713651949878e-28
# El error local en x=8.15 es 1.1593975666103878e-28
# El error local en x=8.2 es 5.150541481036937e-29
# El error local en x=8.25 es 2.276594980705685e-29
# El error local en x=8.3 es 1.0012239600583391e-29
# El error local en x=8.35 es 4.3811635013240416e-30
# El error local en x=8.4 es 1.907482854502115e-30
# El error local en x=8.45 es 8.263137220363483e-31
# El error local en x=8.5 es 3.561579215320238e-31
# El error local en x=8.55 es 1.5274033943324688e-31
# El error local en x=8.6 es 6.517462930151667e-32
# El error local en x=8.65 es 2.767051455467729e-32
# El error local en x=8.7 es 1.168879972050121e-32
# El error local en x=8.75 es 4.912887080839443e-33
# El error local en x=8.8 es 2.054556049468771e-33
# El error local en x=8.85 es 8.548968401016132e-34
# El error local en x=8.9 es 3.5393547571323455e-34
# El error local en x=8.95 es 1.4579723864673722e-34
# El error local en x=9.0 es 5.975709479622661e-35
# El error local en x=9.05 es 2.4369396554127993e-35
# El error local en x=9.1 es 9.88815683078812e-36
# El error local en x=9.15 es 3.992099276780715e-36
# El error local en x=9.2 es 1.6036252249135776e-36
# El error local en x=9.25 es 6.409440568404532e-37
# El error local en x=9.3 es 2.5489024147919937e-37
# El error local en x=9.35 es 1.0085612235245966e-37
# El error local en x=9.4 es 3.9707032618336627e-38
# El error local en x=9.45 es 1.5554241524396992e-38
# El error local en x=9.5 es 6.062428275657752e-39
# El error local en x=9.55 es 2.3510446969373964e-39
# El error local en x=9.6 es 9.071764777431313e-40
# El error local en x=9.65 es 3.4828873049306618e-40
# El error local en x=9.7 es 1.3304664636207933e-40
# El error local en x=9.75 es 5.056912391610859e-41
# El error local en x=9.8 es 1.9124233326894312e-41
# El error local en x=9.85 es 7.196144244154663e-42
# El error local en x=9.9 es 2.6942197986926486e-42
# El error local en x=9.95 es 1.0036531133327164e-42
# El error local en x=10.0 es 3.720075976020836e-43
#
# El error global es: 0.0012035702363380383
#
# a) Derivada el punto x = 0
# b) Derivada en el intervalo −10 ≤ x ≤ 10
# c) Error en cada nodo y error global de la aproximación
# d) Salir
